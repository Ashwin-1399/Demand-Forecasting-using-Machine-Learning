# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import io
import datetime

# %%
# df=pd.read_csv('dataset/combine.csv',parse_dates=True)
# df.head()
df = pd.read_csv('dataset/combine.csv')
df.head()
# Out:
#   Sr.No       Date    Invoice No Challan No Challan Date  P.O. Date  \
# 0     1   1-Mar-17  ARH/J117/100        100     3-Jan-17  12-Dec-16
# 1     2   5-Jan-17  ARH/J117/101        101     5-Jan-17  12-Dec-16
# 2     3   5-Jan-17  ARH/J117/102        102     5-Jan-17  25-Dec-16
# 3     4   6-Jan-17  ARH/J117/103        103     6-Jan-17  25-Dec-16
# 4     5  10-Jan-17  ARH/J117/104        104    10-Jan-17  25-Dec-16
#
#                 Product Name Qty Unit Price Amount Discount Total Value  \
# 0    Side Mount Level Switch   1       6000   6000      10%        5400
# 1   Tubuler Type Level Gauge   5       2900  14500      NaN       14500
# 2   Tubuler Type Level Gauge   2       2900   5800       5%        5510
# 3  Conductivity Level Switch   1       4250   4250      NaN        4250
# 4   Cable Float Level Switch   2      10053  20106      NaN       20106
#
#   Packing & Forwarding Freight CGST(9%) SGST(9%) GST Tax Total Sub Total  \
# 0                  NaN     NaN      486      486           972      6372
# 1                  100      25     1305     1305          2610     17235
# 2                  NaN     NaN    495.9    495.9         991.8    6501.8
# 3                  NaN      60    382.5    382.5           765      5075
# 4                  150     NaN  1809.54  1809.54       3619.08  23875.08
#
#   Rounded Off  Total
# 0         NaN   6372
# 1         NaN  17235
# 2         0.8   6501
# 3         NaN   5075
# 4        0.08  23875

# %%
# seaborn check for missing value
sns.heatmap(df.isnull())

# %%
#remove the missing value
df.drop(['Discount','P.O. Date', 'Packing & Forwarding','Freight','Rounded Off'], axis = 1, inplace=True) 
df.head()
# Out:
#   Sr.No       Date    Invoice No Challan No Challan Date  \
# 0     1   1-Mar-17  ARH/J117/100        100     3-Jan-17
# 1     2   5-Jan-17  ARH/J117/101        101     5-Jan-17
# 2     3   5-Jan-17  ARH/J117/102        102     5-Jan-17
# 3     4   6-Jan-17  ARH/J117/103        103     6-Jan-17
# 4     5  10-Jan-17  ARH/J117/104        104    10-Jan-17
#
#                 Product Name Qty Unit Price Amount Total Value CGST(9%)  \
# 0    Side Mount Level Switch   1       6000   6000        5400      486
# 1   Tubuler Type Level Gauge   5       2900  14500       14500     1305
# 2   Tubuler Type Level Gauge   2       2900   5800        5510    495.9
# 3  Conductivity Level Switch   1       4250   4250        4250    382.5
# 4   Cable Float Level Switch   2      10053  20106       20106  1809.54
#
#   SGST(9%) GST Tax Total Sub Total  Total
# 0      486           972      6372   6372
# 1     1305          2610     17235  17235
# 2    495.9         991.8    6501.8   6501
# 3    382.5           765      5075   5075
# 4  1809.54       3619.08  23875.08  23875

# %%
#convert data to dataframe
data = pd.DataFrame(df) 
data.head()
# Out:
#   Sr.No       Date    Invoice No Challan No Challan Date  \
# 0     1   1-Mar-17  ARH/J117/100        100     3-Jan-17
# 1     2   5-Jan-17  ARH/J117/101        101     5-Jan-17
# 2     3   5-Jan-17  ARH/J117/102        102     5-Jan-17
# 3     4   6-Jan-17  ARH/J117/103        103     6-Jan-17
# 4     5  10-Jan-17  ARH/J117/104        104    10-Jan-17
#
#                 Product Name Qty Unit Price Amount Total Value CGST(9%)  \
# 0    Side Mount Level Switch   1       6000   6000        5400      486
# 1   Tubuler Type Level Gauge   5       2900  14500       14500     1305
# 2   Tubuler Type Level Gauge   2       2900   5800        5510    495.9
# 3  Conductivity Level Switch   1       4250   4250        4250    382.5
# 4   Cable Float Level Switch   2      10053  20106       20106  1809.54
#
#   SGST(9%) GST Tax Total Sub Total  Total
# 0      486           972      6372   6372
# 1     1305          2610     17235  17235
# 2    495.9         991.8    6501.8   6501
# 3    382.5           765      5075   5075
# 4  1809.54       3619.08  23875.08  23875

# %%
# data.to_csv('demandnew.csv')

# %%
#drop the coulmns 
data.drop(['Sub Total'], axis=1,inplace=True)
data.head()
# Out:
#   Sr.No       Date    Invoice No Challan No Challan Date  \
# 0     1   1-Mar-17  ARH/J117/100        100     3-Jan-17
# 1     2   5-Jan-17  ARH/J117/101        101     5-Jan-17
# 2     3   5-Jan-17  ARH/J117/102        102     5-Jan-17
# 3     4   6-Jan-17  ARH/J117/103        103     6-Jan-17
# 4     5  10-Jan-17  ARH/J117/104        104    10-Jan-17
#
#                 Product Name Qty Unit Price Amount Total Value CGST(9%)  \
# 0    Side Mount Level Switch   1       6000   6000        5400      486
# 1   Tubuler Type Level Gauge   5       2900  14500       14500     1305
# 2   Tubuler Type Level Gauge   2       2900   5800        5510    495.9
# 3  Conductivity Level Switch   1       4250   4250        4250    382.5
# 4   Cable Float Level Switch   2      10053  20106       20106  1809.54
#
#   SGST(9%) GST Tax Total  Total
# 0      486           972   6372
# 1     1305          2610  17235
# 2    495.9         991.8   6501
# 3    382.5           765   5075
# 4  1809.54       3619.08  23875

# %%
#rename the filed value
data.rename(columns = {'Date':'Month', 'Total':'Sales'}, inplace = True)

# %%
data.head()
# Out:
#   Sr.No      Month    Invoice No Challan No Challan Date  \
# 0     1   1-Mar-17  ARH/J117/100        100     3-Jan-17
# 1     2   5-Jan-17  ARH/J117/101        101     5-Jan-17
# 2     3   5-Jan-17  ARH/J117/102        102     5-Jan-17
# 3     4   6-Jan-17  ARH/J117/103        103     6-Jan-17
# 4     5  10-Jan-17  ARH/J117/104        104    10-Jan-17
#
#                 Product Name Qty Unit Price Amount Total Value CGST(9%)  \
# 0    Side Mount Level Switch   1       6000   6000        5400      486
# 1   Tubuler Type Level Gauge   5       2900  14500       14500     1305
# 2   Tubuler Type Level Gauge   2       2900   5800        5510    495.9
# 3  Conductivity Level Switch   1       4250   4250        4250    382.5
# 4   Cable Float Level Switch   2      10053  20106       20106  1809.54
#
#   SGST(9%) GST Tax Total  Sales
# 0      486           972   6372
# 1     1305          2610  17235
# 2    495.9         991.8   6501
# 3    382.5           765   5075
# 4  1809.54       3619.08  23875

# %%
#show the sales
data1=data[['Month', 'Sales']] 
data1
# Out:
#          Month   Sales
# 0     1-Mar-17    6372
# 1     5-Jan-17   17235
# 2     5-Jan-17    6501
# 3     6-Jan-17    5075
# 4    10-Jan-17   23875
# ..         ...     ...
# 559  24-Dec-19    3544
# 560  24-Dec-19   55453
# 561  25-Dec-19  100300
# 562  28-Dec-19   49701
# 563        NaN     NaN
#
# [564 rows x 2 columns]

# %%
data1.drop(563,axis=0,inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
data1.tail()
# Out:
#          Month   Sales
# 558  22-Dec-19   58606
# 559  24-Dec-19    3544
# 560  24-Dec-19   55453
# 561  25-Dec-19  100300
# 562  28-Dec-19   49701

# %%
#check the information
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 563 entries, 0 to 562
# Data columns (total 2 columns):
# Month    563 non-null object
# Sales    563 non-null object
# dtypes: object(2)
# memory usage: 13.2+ KB

# %%
type(data1['Month'])
# Out:
# pandas.core.series.Series

# %%
# Convert Month into Datetime
data1['Month']=pd.to_datetime(data1['Month'], errors='coerce')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data1.head()
# Out:
#        Month  Sales
# 0 2017-03-01   6372
# 1 2017-01-05  17235
# 2 2017-01-05   6501
# 3 2017-01-06   5075
# 4 2017-01-10  23875

# %%
#reset index column name of month
data1.set_index('Month',inplace=True)

# %%
data1.head()
# Out:
#             Sales
# Month
# 2017-03-01   6372
# 2017-01-05  17235
# 2017-01-05   6501
# 2017-01-06   5075
# 2017-01-10  23875

# %%
data1.describe()
# Out:
#         Sales
# count     563
# unique    160
# top     23875
# freq       24

# %%
type(data1)
# Out:
# pandas.core.frame.DataFrame

# %%
df = data1.apply(pd.to_numeric, errors='coerce')

# %%
#visualize year wise data
df.plot()

# %%
from statsmodels.tsa.stattools import adfuller
import statsmodels.api as sm

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 563 entries, 2017-03-01 to 2019-12-28
# Data columns (total 1 columns):
# Sales    561 non-null float64
# dtypes: float64(1)
# memory usage: 8.8 KB

# %%
df[np.isnan(df)] = 0

# %%
test_result=adfuller(df['Sales'])

# %%
#define the threshold of sales
def adfuller_test(sales):
    result=adfuller(sales)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations Used']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )
    if result[1] <= 0.05:
        print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary")
    else:
        print("weak evidence against null hypothesis, time series has a unit root, indicating it is non-stationary ")

# %%
#find the lag of sales difference
adfuller_test(df['Sales'])
# Out:
# ADF Test Statistic : -4.529419957273195
# p-value : 0.00017392181048890776
# #Lags Used : 15
# Number of Observations Used : 547
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary

# %%
#difference bewteen sales
df['Sales First Difference'] = df['Sales'] - df['Sales'].shift(1)

# %%
df['Sales'].shift(1)
# Out:
# Month
# 2017-03-01         NaN
# 2017-01-05      6372.0
# 2017-01-05     17235.0
# 2017-01-06      6501.0
# 2017-01-10      5075.0
#                 ...
# 2019-12-22     43992.0
# 2019-12-24     58606.0
# 2019-12-24      3544.0
# 2019-12-25     55453.0
# 2019-12-28    100300.0
# Name: Sales, Length: 563, dtype: float64

# %%
df['Seasonal First Difference']=df['Sales']-df['Sales'].shift(12)

# %%
df.head(14)
# Out:
#               Sales  Sales First Difference  Seasonal First Difference
# Month
# 2017-03-01   6372.0                     NaN                        NaN
# 2017-01-05  17235.0                 10863.0                        NaN
# 2017-01-05   6501.0                -10734.0                        NaN
# 2017-01-06   5075.0                 -1426.0                        NaN
# 2017-01-10  23875.0                 18800.0                        NaN
# 2017-01-11  12390.0                -11485.0                        NaN
# 2017-01-15   3013.0                 -9377.0                        NaN
# 2017-01-16   3577.0                   564.0                        NaN
# 2017-01-18  20650.0                 17073.0                        NaN
# 2017-01-18   4178.0                -16472.0                        NaN
# 2017-01-18   3422.0                  -756.0                        NaN
# 2017-01-19   4708.0                  1286.0                        NaN
# 2017-01-20   6858.0                  2150.0                      486.0
# 2017-01-23   1772.0                 -5086.0                   -15463.0

# %%
adfuller_test(df['Seasonal First Difference'].dropna())
# Out:
# ADF Test Statistic : -8.17112001743144
# p-value : 8.617377961350219e-13
# #Lags Used : 13
# Number of Observations Used : 537
# strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data has no unit root and is stationary

# %%
#monthly sales difference
df['Seasonal First Difference'].plot()

# %%
#monthly sales difference
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(df['Sales'])
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
import statsmodels.api as sm

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df['Seasonal First Difference'].iloc[13:],lags=40,ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(df['Seasonal First Difference'].iloc[13:],lags=40,ax=ax2)

# %%
#apply the arima model
from statsmodels.tsa.arima_model import ARIMA

# %%
#train the model
model=ARIMA(df['Sales'],order=(1,1,1))
model=model.fit()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.Sales   No. Observations:                  562
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -6583.197
# Method:                       css-mle   S.D. of innovations          29508.387
# Date:                Thu, 24 Dec 2020   AIC                          13174.394
# Time:                        15:30:10   BIC                          13191.720
# Sample:                             1   HQIC                         13181.158
#
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            41.2452     41.206      1.001      0.317     -39.518     122.008
# ar.L1.D.Sales    -0.0024      0.044     -0.054      0.957      -0.089       0.084
# ma.L1.D.Sales    -0.9695      0.013    -72.180      0.000      -0.996      -0.943
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1         -423.7638           +0.0000j          423.7638            0.5000
# MA.1            1.0315           +0.0000j            1.0315            0.0000
# -----------------------------------------------------------------------------
# """

# %%
df.values.dtype
# Out:
# dtype('float64')

# %%
#sales difference
df
# Out:
#                Sales  Sales First Difference  Seasonal First Difference
# Month
# 2017-03-01    6372.0                     NaN                        NaN
# 2017-01-05   17235.0                 10863.0                        NaN
# 2017-01-05    6501.0                -10734.0                        NaN
# 2017-01-06    5075.0                 -1426.0                        NaN
# 2017-01-10   23875.0                 18800.0                        NaN
# ...              ...                     ...                        ...
# 2019-12-22   58606.0                 14614.0                    46216.0
# 2019-12-24    3544.0                -55062.0                   -51680.0
# 2019-12-24   55453.0                 51909.0                      229.0
# 2019-12-25  100300.0                 44847.0                    58636.0
# 2019-12-28   49701.0                -50599.0                    25526.0
#
# [563 rows x 3 columns]

# %%
type(model)
# Out:
# statsmodels.tsa.arima_model.ARIMAResultsWrapper

# %%
#month sales 
df = df.sort_values('Month')

df.isnull().sum()
# Out:
# Sales                         0
# Sales First Difference        1
# Seasonal First Difference    12
# dtype: int64

# %%
#group by month and sales
df = df.groupby('Month')['Sales'].sum().reset_index()

# %%
df = df.set_index('Month')
df.index
# Out:
# DatetimeIndex(['2017-01-05', '2017-01-06', '2017-01-10', '2017-01-11',
#                '2017-01-15', '2017-01-16', '2017-01-18', '2017-01-19',
#                '2017-01-20', '2017-01-23',
#                ...
#                '2019-12-09', '2019-12-13', '2019-12-14', '2019-12-16',
#                '2019-12-18', '2019-12-21', '2019-12-22', '2019-12-24',
#                '2019-12-25', '2019-12-28'],
#               dtype='datetime64[ns]', name='Month', length=403, freq=None)

# %%
df = df['Sales'].resample('MS').mean()

# %%
#2017 sales
df['2017':]
# Out:
# Month
# 2017-01-01     13256.076923
# 2017-02-01     51046.200000
# 2017-03-01     35603.000000
# 2017-04-01     62296.442857
# 2017-05-01     22131.857143
# 2017-06-01     21903.200000
# 2017-07-01     46432.909091
# 2017-08-01     43911.833333
# 2017-09-01     16269.800000
# 2017-10-01     48144.000000
# 2017-11-01     46349.857143
# 2017-12-01     54348.500000
# 2018-01-01     26077.846154
# 2018-02-01     41048.400000
# 2018-03-01     21770.733333
# 2018-04-01     32693.722222
# 2018-05-01     19528.944444
# 2018-06-01     20780.142857
# 2018-07-01     52429.785714
# 2018-08-01     30652.733333
# 2018-09-01     14210.750000
# 2018-10-01     14593.000000
# 2018-11-01     47983.066667
# 2018-12-01     31360.761905
# 2019-01-01     12764.357143
# 2019-02-01     51046.200000
# 2019-03-01     40500.333333
# 2019-04-01     54040.750000
# 2019-05-01     18823.625000
# 2019-06-01     21903.200000
# 2019-07-01     47321.545455
# 2019-08-01     48249.250000
# 2019-09-01     20947.000000
# 2019-10-01    130744.000000
# 2019-11-01     55306.000000
# 2019-12-01     66949.571429
# Freq: MS, Name: Sales, dtype: float64

# %%
#month sales 
df.plot(figsize=(15, 6))
plt.show()

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 18, 8

decomposition = sm.tsa.seasonal_decompose(df, model='additive')
fig = decomposition.plot()
plt.show()

# %%
import itertools

# %%
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)
            results = mod.fit()
            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue

# %%
#model fit
mod = sm.tsa.statespace.SARIMAX(df,
                                order=(1, 1, 1),
                                seasonal_order=(1, 1, 0, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()

print(results.summary().tables[1])
# Out:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5867      0.847      0.692      0.489      -1.074       2.247
# ma.L1         -0.8014      0.752     -1.066      0.286      -2.274       0.672
# ar.S.L12      -2.0016      0.597     -3.350      0.001      -3.173      -0.831
# sigma2      8.979e+08   2.95e-10   3.05e+18      0.000    8.98e+08    8.98e+08
# ==============================================================================

# %%
import warnings
import itertools
import numpy as np
import matplotlib.pyplot as plt
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
import pandas as pd
import statsmodels.api as sm
import matplotlib

matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'

# %%
results.plot_diagnostics(figsize=(12, 8))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-e6598af762a9> in <module>
# ----> 1 results.plot_diagnostics(figsize=(12, 8))
#       2 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in plot_diagnostics(self, variable, lags, fig, figsize)
#    2663         ax = fig.add_subplot(224)
#    2664         from statsmodels.graphics.tsaplots import plot_acf
# -> 2665         plot_acf(resid, ax=ax, lags=lags)
#    2666         ax.set_title('Correlogram')
#    2667
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py in plot_acf(x, ax, lags, alpha, use_vlines, unbiased, fft, title, zero, vlines_kwargs, **kwargs)
#     151     else:
#     152         acf_x, confint = acf(x, nlags=nlags, alpha=alpha, fft=fft,
# --> 153                              unbiased=unbiased)
#     154
#     155     _plot_corr(ax, title, acf_x, confint, lags, irregular, use_vlines,
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\stattools.py in acf(x, unbiased, nlags, qstat, fft, alpha, missing)
#     551         varacf[0] = 0
#     552         varacf[1] = 1. / nobs
# --> 553         varacf[2:] *= 1 + 2 * np.cumsum(acf[1:-1]**2)
#     554         interval = stats.norm.ppf(1 - alpha / 2.) * np.sqrt(varacf)
#     555         confint = np.array(lzip(acf - interval, acf + interval))
#
# ValueError: operands could not be broadcast together with shapes (9,) (8,) (9,)

# %%
#future sales observed
pred = results.get_prediction(start=pd.to_datetime('2020-01-01'), dynamic=False)
pred_ci = pred.conf_int()

ax = df['2017':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))

ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)

ax.set_xlabel('Month')
ax.set_ylabel('Sales')
plt.legend()

plt.show()

# %%
#future sale observed
pred_uc = results.get_forecast(steps=100)
pred_ci = pred_uc.conf_int()

ax = df.plot(label='observed', figsize=(14, 7))
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('Furniture Sales')

plt.legend()
plt.show()
